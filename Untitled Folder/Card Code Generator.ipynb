# %%
def card_data_generator():
    '''Generates Card Data as a list of dictionaries (one dictionary for each card).'''
    
    card1 = '{"Card_ID": 1, "Card_Name" : "Cash Wise", "Credit_Score": 645, "Card_Desc": "Cash Wise Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Any", "Threshold" : 1000, "Reward" : 1500}]}'
    card2 = '{"Card_ID": 2, "Card_Name" : "Platinum", "Credit_Score": 600, "Card_Desc": "Platinum Card"}'
    card3 = '{"Card_ID": 3, "Card_Name" : "Hotel", "Credit_Score": 635, "Card_Desc": "Hotel Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Hotel", "Threshold" : 1000, "Reward" : 1500}]}'
    card4 = '{"Card_ID": 4, "Card_Name" : "College", "Credit_Score": 0, "Card_Desc": "College Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Education", "Threshold" : 800, "Reward" : 1000}]}'
    card5 = '{"Card_ID": 5, "Card_Name" : "Visa Signature", "Credit_Score": 680, "Card_Desc": "Visa Signature Card"}'
    card6 = '{"Card_ID": 6, "Card_Name" : "Holiday", "Credit_Score": 618, "Card_Desc": "Holiday Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Travel", "Threshold" : 1000, "Reward" : 500}]}'
    card7 = '{"Card_ID": 7, "Card_Name" : "Shopping", "Credit_Score": 660, "Card_Desc": "Shopping Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Shop_pos", "Threshold" : 500, "Reward" : 1500},\
                                                                                                                    {"Intro_ID" : 2, "Category" : "Shop_net", "Threshold" : 500, "Reward" : 1000}]}'
    card8 = '{"Card_ID": 8, "Card_Name" : "Entertainment", "Credit_Score": 630, "Card_Desc": "Entertainment Card", "Intro" : [{"Intro_ID" : 1, "Category" : "Entertainment", "Threshold" : 1000, "Reward" : 1500}]}'
    card9 = '{"Card_ID": 9, "Card_Name" : "Credit Builder", "Credit_Score": 0, "Card_Desc": "Credit Builder Card"}'
    card1 = json.loads(card1)
    card2 = json.loads(card2)
    card3 = json.loads(card3)
    card4 = json.loads(card4)
    card5 = json.loads(card5)
    card6 = json.loads(card6)
    card7 = json.loads(card7)
    card8 = json.loads(card8)
    card9 = json.loads(card9)
    card_data = []
    card_data.append(card1)
    card_data.append(card2)
    card_data.append(card3)
    card_data.append(card4)
    card_data.append(card5)
    card_data.append(card6)
    card_data.append(card7)
    card_data.append(card8)
    card_data.append(card9)
    return card_data

# %%
import json

# %%
card_data = card_data_generator()

# %%
for card in card_data:
    print('CardDetails cardDetails = new CardDetails()')
    print('cardDetails.setCreditScore(' + str(card['Credit_Score']) +')')
    print('Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()')
    print()
    if 'Intro' in card :
        for intro_offer in card['Intro']:
            print('IntroductoryOffer introductoryOffer = new IntroductoryOffer()')
            print('introductoryOffer.setThreshold(' + str(intro_offer['Threshold']) + ')')
            print('introductoryOffer.setReward(' + str(intro_offer['Reward']) + ')')
            print('purchaseCategoryIntroOfferMap.put(' + 'PurchaseCategory.convert("' + intro_offer['Category'] + '"), introductoryOffer)')
            print()
            
    print('CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)')
    print('map.put(CardType.convert("' + card["Card_Name"] + '"), cardDetails)')
    print("\n// -------------------------------\n")
# Out:
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(645)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(1000)
# introductoryOffer.setReward(1500)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Any"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Cash Wise"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(600)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Platinum"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(635)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(1000)
# introductoryOffer.setReward(1500)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Hotel"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Hotel"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(0)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(800)
# introductoryOffer.setReward(1000)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Education"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("College"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(680)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Visa Signature"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(618)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(1000)
# introductoryOffer.setReward(500)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Travel"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Holiday"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(660)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(500)
# introductoryOffer.setReward(1500)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Shop_pos"), introductoryOffer)
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(500)
# introductoryOffer.setReward(1000)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Shop_net"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Shopping"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(630)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# IntroductoryOffer introductoryOffer = new IntroductoryOffer()
# introductoryOffer.setThreshold(1000)
# introductoryOffer.setReward(1500)
# purchaseCategoryIntroOfferMap.put(PurchaseCategory.convert("Entertainment"), introductoryOffer)
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Entertainment"), cardDetails)
#
# // -------------------------------
#
# CardDetails cardDetails = new CardDetails()
# cardDetails.setCreditScore(0)
# Map<PurchaseCategory, IntroductoryOffer> purchaseCategoryIntroOfferMap = new HashMap<>()
#
# CardDetails.setPurchaseCategoryIntroOfferMap(purchaseCategoryIntroOfferMap)
# map.put(CardType.convert("Credit Builder"), cardDetails)
#
# // -------------------------------
